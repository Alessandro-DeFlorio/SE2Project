# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from autosklearn.regression import AutoSklearnRegressor

# %%
#suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data/train.csv")
df = df.drop(['id'], axis=1)

#split data into train and test
X_train, X_test, y_train, y_test = train_test_split(df.drop('loss', axis=1), df['loss'], test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((150654, 130), (37664, 130), (150654,), (37664,))

# %%
automl = AutoSklearnRegressor(
    time_left_for_this_task=32400,  # Time in seconds for model search
    per_run_time_limit=300,  # Time in seconds for fitting a single model
    n_jobs=-1,  # Use all available cores
    memory_limit=None,  # Auto-sklearn will try to infer the memory limit
    seed=42,  # Set a seed for reproducibility
)

# Fit the AutoSklearnRegressor to your training data
automl.fit(X_train, y_train)
# Out:
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/home/ale/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ale/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ale/anaconda3/lib/python3.9/site-packages/pynisher/limit_function_call.py", line 133, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/home/ale/anaconda3/lib/python3.9/site-packages/autosklearn/smbo.py", line 160, in _calculate_metafeatures_encoded
#     result = calculate_all_metafeatures_encoded_labels(
#   File "/home/ale/anaconda3/lib/python3.9/site-packages/autosklearn/metalearning/metafeatures/metafeatures.py", line 1115, in calculate_all_metafeatures_encoded_labels
#     return calculate_all_metafeatures(
# ...

# %%
# Calculate R^2 score on the test set
r2_score = automl.score(X_test, y_test)
print(f"R^2 score: {r2_score:.2f}")
# Out:
# R^2 score: -0.00

# %%
mse = lambda y, y_pred: np.mean((y - y_pred) ** 2)
y_pred = automl.predict(X_test)
print(f"MSE: {mse(y_test, y_pred):.2f}")
# Out:
# MSE: 8159839.51

# %%
mae = lambda y, y_pred: np.mean(np.abs(y - y_pred))
print(f"MAE: {mae(y_test, y_pred):.2f}")
# Out:
# MAE: 1956.28

# %%
# Save the model
import joblib
joblib.dump(automl, 'autosklearn_model2.pkl')
# Out:
# ['autosklearn_model2.pkl']

# %%
# Load the model from the file
loaded_model = joblib.load('autosklearn_model.pkl')

# Assuming 'new_data' is a pandas DataFrame containing the features for new samples
#predictions = loaded_model.predict(new_data)
